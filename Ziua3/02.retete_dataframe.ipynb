# %%
import requests
import pandas as pd
from pprint import pprint

# %%
response = requests.get("https://dummyjson.com/recipes", {"limit":0})
response_json = response.json()
response_json
# Out:
# {'recipes': [{'id': 1,
#    'name': 'Classic Margherita Pizza',
#    'ingredients': ['Pizza dough',
#     'Tomato sauce',
#     'Fresh mozzarella cheese',
#     'Fresh basil leaves',
#     'Olive oil',
#     'Salt and pepper to taste'],
#    'instructions': ['Preheat the oven to 475°F (245°C).',
#     'Roll out the pizza dough and spread tomato sauce evenly.',
#     'Top with slices of fresh mozzarella and fresh basil leaves.',
#     'Drizzle with olive oil and season with salt and pepper.',
#     'Bake in the preheated oven for 12-15 minutes or until the crust is golden brown.',
#     'Slice and serve hot.'],
#    'prepTimeMinutes': 20,
#    'cookTimeMinutes': 15,
#    'servings': 4,
#    'difficulty': 'Easy',
#    'cuisine': 'Italian',
#    'caloriesPerServing': 300,
#    'tags': ['Pizza', 'Italian'],
#    'userId': 166,
#    'image': 'https://cdn.dummyjson.com/recipe-images/1.webp',
#    'rating': 4.6,
#    'reviewCount': 98,
#    'mealType': ['Dinner']},
#   {'id': 2,
# ...

# %%
type(response_json)
# Out:
# dict

# %%
response_json.keys()
# Out:
# dict_keys(['recipes', 'total', 'skip', 'limit'])

# %%
type(response_json["recipes"])
# Out:
# list

# %%
df = pd.DataFrame(response_json["recipes"])
df.head(2)
# Out:
#    id                      name  \
# 0   1  Classic Margherita Pizza
# 1   2       Vegetarian Stir-Fry
#
#                                          ingredients  \
# 0  [Pizza dough, Tomato sauce, Fresh mozzarella c...
# 1  [Tofu, cubed, Broccoli florets, Carrots, slice...
#
#                                         instructions  prepTimeMinutes  \
# 0  [Preheat the oven to 475°F (245°C)., Roll out ...               20
# 1  [In a wok, heat sesame oil over medium-high he...               15
#
#    cookTimeMinutes  servings difficulty  cuisine  caloriesPerServing  \
# 0               15         4       Easy  Italian                 300
# 1               20         3     Medium    Asian                 250
#
#                             tags  userId  \
# 0               [Pizza, Italian]     166
# 1  [Vegetarian, Stir-fry, Asian]     143
#
#                                             image  rating  reviewCount  \
# 0  https://cdn.dummyjson.com/recipe-images/1.webp     4.6           98
# ...

# %%
df.tail(2)
# Out:
#     id                          name  \
# 48  49  Mediterranean Chickpea Salad
# 49  50    Pineapple Coconut Smoothie
#
#                                           ingredients  \
# 48  [Canned chickpeas, drained and rinsed, Cherry ...
# 49  [Pineapple chunks, fresh or frozen, Coconut mi...
#
#                                          instructions  prepTimeMinutes  \
# 48  [In a large bowl, combine chickpeas, cherry to...               15
# 49  [In a blender, combine pineapple chunks, cocon...               10
#
#     cookTimeMinutes  servings difficulty        cuisine  caloriesPerServing  \
# 48                0         4       Easy  Mediterranean                 220
# 49                0         2       Easy       Smoothie                 200
#
#                                       tags  userId  \
# 48  [Chickpea salad, Mediterranean, Quick]     183
# 49          [Smoothie, Pineapple, Coconut]     172
#
#                                               image  rating  reviewCount  \
# ...

# %%
df.keys()
# Out:
# Index(['id', 'name', 'ingredients', 'instructions', 'prepTimeMinutes',
#        'cookTimeMinutes', 'servings', 'difficulty', 'cuisine',
#        'caloriesPerServing', 'tags', 'userId', 'image', 'rating',
#        'reviewCount', 'mealType'],
#       dtype='object')

# %%
df.describe()
# Out:
#              id  prepTimeMinutes  cookTimeMinutes   servings  \
# count  50.00000        50.000000        50.000000  50.000000
# mean   25.50000        20.100000        16.240000   4.320000
# std    14.57738         8.481071        12.418814   3.254134
# min     1.00000         5.000000         0.000000   1.000000
# 25%    13.25000        15.000000        10.000000   3.000000
# 50%    25.50000        20.000000        15.000000   4.000000
# 75%    37.75000        25.000000        23.750000   4.000000
# max    50.00000        45.000000        45.000000  24.000000
#
#        caloriesPerServing      userId     rating  reviewCount
# count           50.000000   50.000000  50.000000    50.000000
# mean           295.200000  119.220000   4.550000    56.860000
# std            116.885431   57.557173   0.250917    30.450368
# min             90.000000    1.000000   4.100000     0.000000
# 25%            205.000000   80.500000   4.300000    30.500000
# ...

# %%
df.dtypes
# Out:
# id                      int64
# name                   object
# ingredients            object
# instructions           object
# prepTimeMinutes         int64
# cookTimeMinutes         int64
# servings                int64
# difficulty             object
# cuisine                object
# caloriesPerServing      int64
# tags                   object
# userId                  int64
# image                  object
# rating                float64
# reviewCount             int64
# mealType               object
# dtype: object

# %%
df["difficulty"].unique()
# Out:
# array(['Easy', 'Medium'], dtype=object)

# %%
df.keys()
# Out:
# Index(['id', 'name', 'ingredients', 'instructions', 'prepTimeMinutes',
#        'cookTimeMinutes', 'servings', 'difficulty', 'cuisine',
#        'caloriesPerServing', 'tags', 'userId', 'image', 'rating',
#        'reviewCount', 'mealType'],
#       dtype='object')

# %% [markdown]
# # Creaza un nou DataFrame cu coloanele filtrate

# %%
df[ [ 'id', 'name', 'ingredients', 'instructions' ] ].head(2)
# Out:
#    id                      name  \
# 0   1  Classic Margherita Pizza
# 1   2       Vegetarian Stir-Fry
#
#                                          ingredients  \
# 0  [Pizza dough, Tomato sauce, Fresh mozzarella c...
# 1  [Tofu, cubed, Broccoli florets, Carrots, slice...
#
#                                         instructions
# 0  [Preheat the oven to 475°F (245°C)., Roll out ...
# 1  [In a wok, heat sesame oil over medium-high he...

# %% [markdown]
# # DataFrame-ul initial ramane neschimbat

# %%
df.head(2)
# Out:
#    id                      name  \
# 0   1  Classic Margherita Pizza
# 1   2       Vegetarian Stir-Fry
#
#                                          ingredients  \
# 0  [Pizza dough, Tomato sauce, Fresh mozzarella c...
# 1  [Tofu, cubed, Broccoli florets, Carrots, slice...
#
#                                         instructions  prepTimeMinutes  \
# 0  [Preheat the oven to 475°F (245°C)., Roll out ...               20
# 1  [In a wok, heat sesame oil over medium-high he...               15
#
#    cookTimeMinutes  servings difficulty  cuisine  caloriesPerServing  \
# 0               15         4       Easy  Italian                 300
# 1               20         3     Medium    Asian                 250
#
#                             tags  userId  \
# 0               [Pizza, Italian]     166
# 1  [Vegetarian, Stir-fry, Asian]     143
#
#                                             image  rating  reviewCount  \
# 0  https://cdn.dummyjson.com/recipe-images/1.webp     4.6           98
# ...

# %%
described_df = df.describe()
type(described_df)
# Out:
# pandas.core.frame.DataFrame

# %%
described_df.keys()
# Out:
# Index(['id', 'prepTimeMinutes', 'cookTimeMinutes', 'servings',
#        'caloriesPerServing', 'userId', 'rating', 'reviewCount'],
#       dtype='object')

# %%
described_df
# Out:
#              id  prepTimeMinutes  cookTimeMinutes   servings  \
# count  50.00000        50.000000        50.000000  50.000000
# mean   25.50000        20.100000        16.240000   4.320000
# std    14.57738         8.481071        12.418814   3.254134
# min     1.00000         5.000000         0.000000   1.000000
# 25%    13.25000        15.000000        10.000000   3.000000
# 50%    25.50000        20.000000        15.000000   4.000000
# 75%    37.75000        25.000000        23.750000   4.000000
# max    50.00000        45.000000        45.000000  24.000000
#
#        caloriesPerServing      userId     rating  reviewCount
# count           50.000000   50.000000  50.000000    50.000000
# mean           295.200000  119.220000   4.550000    56.860000
# std            116.885431   57.557173   0.250917    30.450368
# min             90.000000    1.000000   4.100000     0.000000
# 25%            205.000000   80.500000   4.300000    30.500000
# ...

# %% [markdown]
# # Filtrez dataframe-ul dupa coloanele numerice

# %%
numeric_df = df [ ['id', 'prepTimeMinutes', 'cookTimeMinutes', 'servings',
       'caloriesPerServing', 'userId', 'rating', 'reviewCount'] ]
numeric_df.head(2)
# Out:
#    id  prepTimeMinutes  cookTimeMinutes  servings  caloriesPerServing  userId  \
# 0   1               20               15         4                 300     166
# 1   2               15               20         3                 250     143
#
#    rating  reviewCount
# 0     4.6           98
# 1     4.7           26
