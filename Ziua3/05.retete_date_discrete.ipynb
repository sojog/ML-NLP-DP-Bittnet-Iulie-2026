# %%
import requests
import pandas as pd
from pprint import pprint

# %%
response = requests.get("https://dummyjson.com/recipes", {"limit":0})
response_json = response.json()

# %%
df = pd.DataFrame(response_json["recipes"])
df.head(2)
# Out:
#    id                      name  \
# 0   1  Classic Margherita Pizza
# 1   2       Vegetarian Stir-Fry
#
#                                          ingredients  \
# 0  [Pizza dough, Tomato sauce, Fresh mozzarella c...
# 1  [Tofu, cubed, Broccoli florets, Carrots, slice...
#
#                                         instructions  prepTimeMinutes  \
# 0  [Preheat the oven to 475°F (245°C)., Roll out ...               20
# 1  [In a wok, heat sesame oil over medium-high he...               15
#
#    cookTimeMinutes  servings difficulty  cuisine  caloriesPerServing  \
# 0               15         4       Easy  Italian                 300
# 1               20         3     Medium    Asian                 250
#
#                             tags  userId  \
# 0               [Pizza, Italian]     166
# 1  [Vegetarian, Stir-fry, Asian]     143
#
#                                             image  rating  reviewCount  \
# 0  https://cdn.dummyjson.com/recipe-images/1.webp     4.6           98
# 1  https://cdn.dummyjson.com/recipe-images/2.webp     4.7           26
#
#    mealType
# 0  [Dinner]
# 1   [Lunch]

# %%
numeric_keys = df.describe().keys()
numeric_keys
# Out:
# Index(['id', 'prepTimeMinutes', 'cookTimeMinutes', 'servings',
#        'caloriesPerServing', 'userId', 'rating', 'reviewCount'],
#       dtype='object')

# %%
df = df.drop(numeric_keys,  axis=1)
df.head(2)
# Out:
#                        name  \
# 0  Classic Margherita Pizza
# 1       Vegetarian Stir-Fry
#
#                                          ingredients  \
# 0  [Pizza dough, Tomato sauce, Fresh mozzarella c...
# 1  [Tofu, cubed, Broccoli florets, Carrots, slice...
#
#                                         instructions difficulty  cuisine  \
# 0  [Preheat the oven to 475°F (245°C)., Roll out ...       Easy  Italian
# 1  [In a wok, heat sesame oil over medium-high he...     Medium    Asian
#
#                             tags  \
# 0               [Pizza, Italian]
# 1  [Vegetarian, Stir-fry, Asian]
#
#                                             image  mealType
# 0  https://cdn.dummyjson.com/recipe-images/1.webp  [Dinner]
# 1  https://cdn.dummyjson.com/recipe-images/2.webp   [Lunch]

# %%
df["image"]
# Out:
# 0      https://cdn.dummyjson.com/recipe-images/1.webp
# 1      https://cdn.dummyjson.com/recipe-images/2.webp
# 2      https://cdn.dummyjson.com/recipe-images/3.webp
# 3      https://cdn.dummyjson.com/recipe-images/4.webp
# 4      https://cdn.dummyjson.com/recipe-images/5.webp
# 5      https://cdn.dummyjson.com/recipe-images/6.webp
# 6      https://cdn.dummyjson.com/recipe-images/7.webp
# 7      https://cdn.dummyjson.com/recipe-images/8.webp
# 8      https://cdn.dummyjson.com/recipe-images/9.webp
# 9     https://cdn.dummyjson.com/recipe-images/10.webp
# 10    https://cdn.dummyjson.com/recipe-images/11.webp
# 11    https://cdn.dummyjson.com/recipe-images/12.webp
# 12    https://cdn.dummyjson.com/recipe-images/13.webp
# 13    https://cdn.dummyjson.com/recipe-images/14.webp
# 14    https://cdn.dummyjson.com/recipe-images/15.webp
# 15    https://cdn.dummyjson.com/recipe-images/16.webp
# 16    https://cdn.dummyjson.com/recipe-images/17.webp
# 17    https://cdn.dummyjson.com/recipe-images/18.webp
# 18    https://cdn.dummyjson.com/recipe-images/19.webp
# 19    https://cdn.dummyjson.com/recipe-images/20.webp
# 20    https://cdn.dummyjson.com/recipe-images/21.webp
# 21    https://cdn.dummyjson.com/recipe-images/22.webp
# 22    https://cdn.dummyjson.com/recipe-images/23.webp
# 23    https://cdn.dummyjson.com/recipe-images/24.webp
# 24    https://cdn.dummyjson.com/recipe-images/25.webp
# 25    https://cdn.dummyjson.com/recipe-images/26.webp
# 26    https://cdn.dummyjson.com/recipe-images/27.webp
# 27    https://cdn.dummyjson.com/recipe-images/28.webp
# 28    https://cdn.dummyjson.com/recipe-images/29.webp
# 29    https://cdn.dummyjson.com/recipe-images/30.webp
# 30    https://cdn.dummyjson.com/recipe-images/31.webp
# 31    https://cdn.dummyjson.com/recipe-images/32.webp
# 32    https://cdn.dummyjson.com/recipe-images/33.webp
# 33    https://cdn.dummyjson.com/recipe-images/34.webp
# 34    https://cdn.dummyjson.com/recipe-images/35.webp
# 35    https://cdn.dummyjson.com/recipe-images/36.webp
# 36    https://cdn.dummyjson.com/recipe-images/37.webp
# 37    https://cdn.dummyjson.com/recipe-images/38.webp
# 38    https://cdn.dummyjson.com/recipe-images/39.webp
# 39    https://cdn.dummyjson.com/recipe-images/40.webp
# 40    https://cdn.dummyjson.com/recipe-images/41.webp
# 41    https://cdn.dummyjson.com/recipe-images/42.webp
# 42    https://cdn.dummyjson.com/recipe-images/43.webp
# 43    https://cdn.dummyjson.com/recipe-images/44.webp
# 44    https://cdn.dummyjson.com/recipe-images/45.webp
# 45    https://cdn.dummyjson.com/recipe-images/46.webp
# 46    https://cdn.dummyjson.com/recipe-images/47.webp
# 47    https://cdn.dummyjson.com/recipe-images/48.webp
# 48    https://cdn.dummyjson.com/recipe-images/49.webp
# 49    https://cdn.dummyjson.com/recipe-images/50.webp
# Name: image, dtype: object
