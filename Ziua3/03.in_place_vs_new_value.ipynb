# %%
o_lista = [3, 2, 4, 6, 5, 7, 8, 1, 9]

# %% [markdown]
# # New Value

# %%
sorted(o_lista)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
o_lista
# Out:
# [3, 2, 4, 6, 5, 7, 8, 1, 9]

# %%
o_noua_lista = sorted(o_lista)
o_noua_lista
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# # In place

# %%
o_lista
# Out:
# [3, 2, 4, 6, 5, 7, 8, 1, 9]

# %%
o_lista.sort()

# %%
print(o_lista.sort())
# Out:
# None

# %%
o_lista
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
