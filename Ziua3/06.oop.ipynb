# %%
class Masina:
    def __init__(self, capacitate, km):
        self.capacitate = capacitate
        self.km = km

# %%
audi = Masina("mare", 100)
audi.km
# Out:
# 100

# %%
audi.capacitate
# Out:
# 'mare'

# %%
audi.model = "ultim"

# %%
audi.model
# Out:
# 'ultim'

# %%
bmw = Masina("mare", 100)

# %%
bmw.model
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 bmw.model
#
# AttributeError: 'Masina' object has no attribute 'model'
