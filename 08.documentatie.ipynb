# %%
""" Acesta este un 


string multilinie """
# Out:
# ' Acesta este un \n\n\nstring multilinie '

# %%
def functie_cu_documentatie():
    """Aceasta este documentatia functiei """

    print("Orice...")

# %%
functie_cu_documentatie()
