# %%
10 or 20
# Out:
# 10

# %%
10 and 20
# Out:
# 20

# %%
10 or 0
# Out:
# 10

# %%
0 and 20
# Out:
# 0

# %%
print("True and True = ", True and True)
print("True and False = ", True and False)
print("False and True = ", False and True)
print("False and False = ", False and False)
# Out:
# True and True =  True
# True and False =  False
# False and True =  False
# False and False =  False

# %%
print("1 and 1 = ", 1 and 1)
print("1 and 0 = ", 1 and 0)
print("0 and 1 = ", 0 and 1)
print("0 and 0 = ", 0 and 0)
# Out:
# 1 and 1 =  1
# 1 and 0 =  0
# 0 and 1 =  0
# 0 and 0 =  0

# %%
bool(100)
# Out:
# True

# %%
bool(-100)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool("salutare")
# Out:
# True

# %%
bool("0")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool(" ")
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool([1,])
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
"salut" or "altceva"
# Out:
# 'salut'

# %%
x = input("Introdu ceva") or 30
x
# Out:
# 30

# %%
x = 10
x << 2
# Out:
# 40

# %%
x = 10
x << 1
# Out:
# 20

# %%
x = 10
y = 2
x ^ y
# Out:
# 8

# %%
# x @ y - functioneaza doar in numpy
