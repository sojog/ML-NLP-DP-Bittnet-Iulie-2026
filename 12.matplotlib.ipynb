# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(10, 20)
plt.show()

# %%
plt.scatter(10, 20);

# %%
plt.scatter([10, 7], [20, 8]);

# %%
plt.scatter([10, 7], [20, 8]);
plt.xlabel("Coordonata X");
plt.ylabel("Coordonata Y");

# %%
plt.scatter([10, 7, 3], [20, 8, 7]);
plt.xlabel("Coordonata X");
plt.ylabel("Coordonata Y");

# %%
plt.plot([10, 7, 3], [20, 8, 7]);
plt.xlabel("Coordonata X");
plt.ylabel("Coordonata Y");

# %%
plt.scatter([10, 7, 3], [20, 8, 7]);
plt.plot([10, 7, 3], [20, 8, 7]);
plt.xlabel("Coordonata X");
plt.ylabel("Coordonata Y");

# %%
plt.scatter([10, 7, 3], [20, 8, 7]);
plt.scatter([11, 8, 4], [19, 7, 6]);
plt.plot([10, 7, 3], [20, 8, 7]);
plt.xlabel("Coordonata X");
plt.ylabel("Coordonata Y");
