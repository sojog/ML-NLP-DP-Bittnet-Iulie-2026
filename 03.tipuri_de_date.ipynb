# %%
x = 2
print(x)
# Out:
# 2

# %%
x += 1
print(x)
# Out:
# 3

# %%
x
# Out:
# 3

# %% [markdown]
# Acesta este un markdown

# %% [markdown]
# # Markdown cu un hashtag

# %% [markdown]
# ## Markdown cu 2 hashtaguri

# %%
x = True
print(x, type(x))
# Out:
# True <class 'bool'>

# %%
x = 2
print(x, type(x))
# Out:
# 2 <class 'int'>

# %%
x = 2.41
print(x, type(x))
# Out:
# 2.41 <class 'float'>

# %%
x = "312Hrfas"
print(x, type(x))
# Out:
# 312Hrfas <class 'str'>

# %% [markdown]
# # Tipuri compuse

# %%
list_x = [10, 20, 30, True, 41.51, "String", ["hello"]]
print(list_x, type(list_x))
# Out:
# [10, 20, 30, True, 41.51, 'String', ['hello']] <class 'list'>

# %%
list_x.append(100)
list_x
# Out:
# [10, 20, 30, True, 41.51, 'String', ['hello'], 100]

# %%
tuple_x = (10, 20, 30, True, 41.51, "String", ["hello"])
print(tuple_x, type(tuple_x))
# Out:
# (10, 20, 30, True, 41.51, 'String', ['hello']) <class 'tuple'>

# %% [markdown]
# ### Tuple-uri sunt imutabile

# %%
tuple_x.append(100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 tuple_x.append(100)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
dictionar_x = {
    "cheie" : "valoare"
}
dictionar_x
# Out:
# {'cheie': 'valoare'}

# %%
dictionar_x = {
    "cheie" : "valoare", 100:300, "100":"hello", None:None, True:False, (10, 20, [30]):"bine", 
}
dictionar_x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 dictionar_x = {
#       2     "cheie" : "valoare", 100:300, "100":"hello", None:None, True:False, (10, 20, [30]):"bine",
#       3 }
#       4 dictionar_x
#
# TypeError: cannot use 'tuple' as a dict key (unhashable type: 'list')

# %%
dictionar_x[100]
# Out:
# 300

# %%
valoare = (10, 20, [30])
valoare
# Out:
# (10, 20, [30])

# %%
type(valoare)
# Out:
# tuple

# %%
valoare.append(100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 valoare.append(100)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
valoare[2]
# Out:
# [30]

# %%
valoare[2].append(100)

# %%
valoare
# Out:
# (10, 20, [30, 100])
